# %%
import pandas as pd
import seaborn as sns
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sb
from datetime import datetime
import seaborn as sns
from collections import Counter
# %matplotlib inline

# %%
df=pd.read_excel(r'ParticipantsEmotionAvatarDatabase.xlsx')

# %%
df.tail()
# Out:
#     Participant Id.          SDD Age (num)  SDD AGE SDD Gender (alfa)  \
# 201         PV33MTP                     67      3.0               Man
# 202         PV33PCP                     65      3.0               Man
# 203         PV33VZM                     62      3.0               Man
# 204             NaN                    NaN      NaN               NaN
# 205             NaN  SOCIODEMOGRAPHIC DATA      NaN               NaN
#
#      SDD GENDER SDD Race (alfa)  SDD RACE SDD Civil State (alfa)  \
# 201         2.0       Caucasian       1.0                Married
# 202         2.0       Caucasian       1.0                Married
# 203         2.0       Caucasian       1.0                Married
# 204         NaN             NaN       NaN                    NaN
# 205         NaN             NaN       NaN                    NaN
#
#      SDD CIVIL STATE SDD Province (alfa)  ...  PANAS 17. Attentive PANAS 17  \
# ...

# %%
fig=plt.figure(figsize=(13,5))
ax=sns.countplot(x='PANAS 18. Jittery',data=df,palette='husl')

# %%
percent_Male = 101
percent_Female = 105
colors = ['#66b3ff','#ff9999']

values =[percent_Male, percent_Female]
labels =['Male', 'Female']
mpl.rcParams['font.size'] = 13

plt.pie(values, labels=labels, colors=colors,startangle=90, pctdistance=0.85, autopct='%1.1f%%')
#draw circle
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.axis('equal')  
plt.tight_layout()
plt.title("Gender Percentage")
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-840db14fd386> in <module>
# ----> 1 sb.countplot(df.SDD_Gender(alfa))
#       2 total_male=0
#       3 print('Total People[0,1]: ',len(df.SDD_Gender(alfa)))
#       4 total_male=[i for i in df.SDD_Gender_alfa if i=='Man']
#       5 a=len(total_male)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'SDD_Gender'

# %%
df.columns

# %%
df.columns=['Participant_Id.', 'SDD_Age_num', 'SDD_AGE', 'SDD_Gender_alfa',
       'SDD_GENDER', 'SDD_Race_alfa', 'SDD_RACE', 'SDD_Civil_State_alfa',
       'SDD CIVIL STATE', 'SDD Province_alfa', 'SDD_PROVINCE',
       'SDD_Residence_alfa', 'SDD_RESIDENCE', 'SDD_Education_Level_alfa',
       'SDD_EDUCATION LEVEL', 'SDD_Professional Situation_alfa',
       'SDD_PROFESSIONAL_SITUATION', 'PANAS_Interested', 'PANAS_01',
       'PANAS_Distressed', 'PANAS_02', 'PANAS_Excited', 'PANAS 03',
       'PANAS_Upset', 'PANAS 04', 'PANAS 05. Strong', 'PANAS_05',
       'PANAS_Guilty', 'PANAS_06', 'PANAS_Scared', 'PANAS_07',
       'PANAS_Hostile', 'PANAS_08', 'PANAS_Enthusiastic', 'PANAS_09',
       'PANAS_Proud', 'PANAS_10', 'PANAS_Irritable', 'PANAS_11',
       'PANAS_Alert', 'PANAS_12', 'PANAS_Ashamed', 'PANAS_13',
       'PANAS_Inspired', 'PANA_14', 'PANAS_Nervous', 'PANAS_15',
       'PANAS_Determined', 'PANAS_16', 'PANAS_Attentive', 'PANAS_17',
       'PANAS_Jittery', 'PANAS_18', 'PANAS_Active', 'PANAS_19',
       'PANAS_Afraid', 'PANAS_20', 'Positive_Affect', 'Negative_Affect']

# %%
df.head()
# Out:
#   Participant_Id. SDD_Age_num  SDD_AGE SDD_Gender_alfa  SDD_GENDER  \
# 0         PM11AGD          23      1.0           Woman         1.0
# 1         PM11AMF          24      1.0           Woman         1.0
# 2         PM11APP          24      1.0           Woman         1.0
# 3         PM11ATG          25      1.0           Woman         1.0
# 4         PM11CSM          26      1.0           Woman         1.0
#
#   SDD_Race_alfa  SDD_RACE SDD_Civil_State_alfa  SDD CIVIL STATE  \
# 0     Caucasian       1.0               Single              1.0
# 1     Caucasian       1.0               Single              1.0
# 2     Caucasian       1.0               Single              1.0
# 3     Caucasian       1.0               Single              1.0
# 4     Caucasian       1.0               Single              1.0
#
#   SDD Province_alfa  ...  PANAS_Attentive PANAS_17  \
# 0          Albacete  ...       Moderately      3.0
# 1          Albacete  ...      Quite a bit      4.0
# ...

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='SDD_Age_num',data=df,palette='husl')
dff=df

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='SDD_Civil_State_alfa',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='PANAS_Attentive',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='PANAS_Jittery',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='PANAS_Active',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='PANAS_Afraid',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='Positive_Affect',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='Negative_Affect',data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[0],data=df,palette='husl')

# %%
abc=df.columns[3:57 :2]
print(abc)
# Out:
# Index(['SDD_Gender_alfa', 'SDD_Race_alfa', 'SDD_Civil_State_alfa',
#        'SDD Province_alfa', 'SDD_Residence_alfa', 'SDD_Education_Level_alfa',
#        'SDD_Professional Situation_alfa', 'PANAS_Interested',
#        'PANAS_Distressed', 'PANAS_Excited', 'PANAS_Upset', 'PANAS 05. Strong',
#        'PANAS_Guilty', 'PANAS_Scared', 'PANAS_Hostile', 'PANAS_Enthusiastic',
#        'PANAS_Proud', 'PANAS_Irritable', 'PANAS_Alert', 'PANAS_Ashamed',
#        'PANAS_Inspired', 'PANAS_Nervous', 'PANAS_Determined',
#        'PANAS_Attentive', 'PANAS_Jittery', 'PANAS_Active', 'PANAS_Afraid'],
#       dtype='object')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[0],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[1],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[2],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[3],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[4],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[5],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[6],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[7],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[8],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[9],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[10],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[11],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[12],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[13],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[14],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[15],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[16],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[17],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[18],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[19],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[20],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[21],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[22],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[23],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[24],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[25],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[26],data=df,palette='husl')

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x=abc[27],data=df,palette='husl')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-534-4225b89c6b57> in <module>
#       1 fig=plt.figure(figsize=(25,10))
# ----> 2 ax=sns.countplot(x=abc[27],data=df,palette='husl')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3956         if is_scalar(key):
#    3957             key = com.cast_scalar_indexer(key)
# -> 3958             return getitem(key)
#    3959
#    3960         if isinstance(key, slice):
#
# IndexError: index 27 is out of bounds for axis 0 with size 27

# %%
fig=plt.figure(figsize=(25,10))
ax=sns.countplot(x='Positive_Affect',data=df,palette='husl')

# %%
#df.pop(df.columns[0: :2])
df = df.drop(df.columns[3:57 :2], axis=1)

# %%
df=df.drop('Participant_Id.',axis=1)

# %%
df=df.drop('SDD_AGE',axis=1)

# %%
df.head()
# Out:
#   SDD_Age_num  SDD_GENDER  SDD_RACE  SDD CIVIL STATE  SDD_PROVINCE  \
# 0          23         1.0       1.0              1.0           2.0
# 1          24         1.0       1.0              1.0           2.0
# 2          24         1.0       1.0              1.0           1.0
# 3          25         1.0       1.0              1.0           1.0
# 4          26         1.0       1.0              1.0           1.0
#
#    SDD_RESIDENCE  SDD_EDUCATION LEVEL  SDD_PROFESSIONAL_SITUATION  PANAS_01  \
# 0            1.0                  1.0                         3.0       3.0
# 1            1.0                  1.0                         3.0       4.0
# 2            1.0                  1.0                         3.0       3.0
# 3            1.0                  1.0                         1.0       3.0
# 4            1.0                  1.0                         3.0       3.0
#
#    PANAS_02  ...  PANAS_13  PANA_14  PANAS_15  PANAS_16  PANAS_17  PANAS_18  \
# ...

# %%
for i in range(len(data.Positive_Affect)):
    if(data.Positive_Affect[i]>=20 and data.Positive_Affect[i]<=25):
        data.Positive_Affect[i]=1
    elif(data.Positive_Affect[i]>25 and data.Positive_Affect[i]<=30):
        data.Positive_Affect[i]=2
    elif(data.Positive_Affect[i]>30 and data.Positive_Affect[i]<=35):
        data.Positive_Affect[i]=3
    elif(data.Positive_Affect[i]>35 and data.Positive_Affect[i]<=40):
        data.Positive_Affect[i]=4
    else:
        data.Positive_Affect[i]=5
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
data.Positive_Affect[0]
data=df

# %%
data.head()
# Out:
#   SDD_Age_num  SDD_GENDER  SDD_RACE  SDD CIVIL STATE  SDD_PROVINCE  \
# 0          23         1.0       1.0              1.0           2.0
# 1          24         1.0       1.0              1.0           2.0
# 2          24         1.0       1.0              1.0           1.0
# 3          25         1.0       1.0              1.0           1.0
# 4          26         1.0       1.0              1.0           1.0
#
#    SDD_RESIDENCE  SDD_EDUCATION LEVEL  SDD_PROFESSIONAL_SITUATION  PANAS_01  \
# 0            1.0                  1.0                         3.0       3.0
# 1            1.0                  1.0                         3.0       4.0
# 2            1.0                  1.0                         3.0       3.0
# 3            1.0                  1.0                         1.0       3.0
# 4            1.0                  1.0                         3.0       3.0
#
#    PANAS_02  ...  PANAS_13  PANA_14  PANAS_15  PANAS_16  PANAS_17  PANAS_18  \
# ...
